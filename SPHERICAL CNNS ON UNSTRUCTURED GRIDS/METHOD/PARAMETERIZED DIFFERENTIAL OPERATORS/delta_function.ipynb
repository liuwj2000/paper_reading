# %% [markdown]
# # delta 函数

# %% [markdown]
# ##  背景引入

# %% [markdown]
# ### 物理背景

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 定义

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 高维 delta 函数

# %% [markdown]
# ![image.png](attachment:image.png)
# 一个是只有这一个点有东西，一个是只有这一条线有东西
